# %% [markdown]
# # **Visualisation des données avec Python en utilisant la bibliothèque, pandas, numpy et Matplotlib**

# %%
# Install packages
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
#réduire la taille de tous les graph
# plt.rcParams['figure.figsize'] = [6, 2]

# %%
# Créer des données
data = {
    "age": np.random.randint(18, 64, 9),
    "taille" : np.random.randint(150, 200, 9),
    "poids" : np.random.randint(40, 100, 9),
    "genre" : np.random.choice([1, 0], 9),
    "etude" : np.random.choice([1, 2, 3], 9)
}

df = pd.DataFrame(data)

df.tail(2)
# Out:
#    age  taille  poids  genre  etude
# 7   33     191     53      0      1
# 8   49     192     60      1      1

# %% [markdown]
# #**Plot()**
# Mettre toutes les légendes à droite avec  : `plt.legend(loc='upper right')`

# %% [markdown]
# #**Graphique en courbe ou en ligne**
#
# df.plot(kind = "line")  ou df.plot.line()

# %%
df.plot()
# Out:
# <Axes: >

# %% [markdown]
# #**Scatter Plot**

# %%
df.plot(kind = "scatter",
        x = "age", y = "poids")
# Out:
# <Axes: xlabel='age', ylabel='poids'>

# %%
plt.scatter(data = df,
        y = "poids", x = "genre")

# %% [markdown]
# #**Bar Chart**
# df.plot.bar()

# %%
df.plot(kind = 'bar')

# %% [markdown]
# Graphique à barres empilées

# %%
df.plot.bar(stacked = True)

# %% [markdown]
# Graphique à barres Horizontales

# %%
# bar horizontal
df.plot.barh()

# %% [markdown]
# #**Histogramme**

# %%
df.plot(kind ="hist")

# %% [markdown]
# #**Area plot**
#
# df.plot.area()

# %%
df.plot(kind = "area")

# %% [markdown]
# #**Box plot**
#
# df.plot(kind = "box")

# %%
df.plot.box()
# Out:
# <Axes: >

# %% [markdown]
# #**Graphique en secteur**

# %%
df.plot.pie(y="age")
# Out:
# <Axes: ylabel='age'>

# %% [markdown]
# #**Graphique de densité**
# df[["age", "poids"]].plot.kde()

# %%
df[["age", "poids"]].plot(kind = 'kde')
# Out:
# <Axes: ylabel='Density'>
